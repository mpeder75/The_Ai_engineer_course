# %%
sentense = "HER CAT NAME IS LUNA"

# %%
lower_sentense = sentense.lower()
print(lower_sentense)
# Out:
# her cat name is luna

# %%
sentence_list = ['Could you pass me the TV remote?',
                  'It is IMPOSSISBLE to find this hotel',
                 'Want to go for dinner on Tuesday?']

# %%
lower_sentence_list = [x.lower() for x in sentence_list]
print(lower_sentence_list)
# Out:
# ['could you pass me the tv remote?', 'it is impossisble to find this hotel', 'want to go for dinner on tuesday?']
