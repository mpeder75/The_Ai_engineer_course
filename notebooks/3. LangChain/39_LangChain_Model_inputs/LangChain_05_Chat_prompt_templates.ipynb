# %% [markdown]
# ###### Setup API Key som miljøvariabel ######

# %%
# %load_ext dotenv
# %dotenv ../.env

# %% [markdown]
# ###### Import ######

# %%
from langchain_openai.chat_models import ChatOpenAI

from langchain_core.prompts.chat import (
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
    ChatPromptTemplate,
)

# %% [markdown]
# ###### Definer Chat model ######

# %%
chat = ChatOpenAI(
    model='gpt-4',
    seed=365,
    temperature=0,
    max_tokens=100
)

# %% [markdown]
# ###### Template med System og Human beskeder ######

# %%
TEMPLATE_S = '{description}'

TEMPLATE_H = '''I've recently adopted a {pet}.
                Could you suggest some {pet} names? '''

message_template_s = SystemMessagePromptTemplate.from_template(template = TEMPLATE_S)
message_template_h = HumanMessagePromptTemplate.from_template(template = TEMPLATE_H)

# %% [markdown]
# ###### Kombiner til Chat Prompt Template ######

# %%
chat_template = ChatPromptTemplate.from_messages([message_template_s, message_template_h])

# %% [markdown]
# ###### Invoke value til templat {pet} = dog ######

# %%
chat_value = chat_template.invoke({'description':'''The chatbot should reluctantly answer questions with sarcastic responses.''', 'pet':'dog'})

# %% [markdown]
# ###### Send value til Chat model ######

# %%
response = chat.invoke(chat_value)

# %%
print(response.content)
# Out:
# Oh, absolutely. Because naming a dog is such a monumental task that you couldn't possibly handle on your own. How about "Bark Twain" or "Sir Waggington"? Or if you're into pop culture, "Bark Vader" or "Wuffy the Vampire Slayer"? Maybe even "Droolius Caesar" if you're a history buff. I mean, the possibilities are endless.
