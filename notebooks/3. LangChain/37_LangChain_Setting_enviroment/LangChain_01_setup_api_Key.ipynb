# %%
import os

# %% [markdown]
# ###### Setting up API Key til LangChain ######

# %%
# %load_ext dotenv
# %dotenv ../.env

# %% [markdown]
# ###### Verifying the API Key ######

# %%
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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
