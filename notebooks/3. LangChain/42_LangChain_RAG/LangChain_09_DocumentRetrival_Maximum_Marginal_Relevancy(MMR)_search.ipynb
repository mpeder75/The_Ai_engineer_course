# %% [markdown]
# ### Retrieval: Vectorstore retriver

# %% [markdown]
# ###### Setup API Key som miljøvariabel ######

# %%
# %load_ext dotenv
# %dotenv ../.env

# %% [markdown]
# ###### Import ######

# %%
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

# %% [markdown]
# ###### Opret Embedding Model instans ######

# %%
embedding = OpenAIEmbeddings(model='text-embedding-ada-002')

# %% [markdown]
# ###### Opret Chroma Vectorstore ######

# %%
vectorstore = Chroma(persist_directory = "./chroma_db",
                     embedding_function = embedding)

# %% [markdown]
# ###### Spørgsmål ######

# %%
question = "What software do data scientists use?"

# %% [markdown]
# ###### Max Marginal Relevancy Search ######

# %%
retrieved_docs = vectorstore.max_marginal_relevance_search(
    query=question,
    k=3,
    lambda_mult = 0.1)

# %%
retrieved_docs = vectorstore.max_marginal_relevance_search(
    query=question,
    k=3,
    lambda_mult = 1,
    filter = {"Lecture Title":
            "Programming Languages & Software Employed in Data Science - All the Tools You Need"})

# %%
for i in retrieved_docs:
    print(f"Page Content: {i.page_content}\n----------\nLecture Title:{i.metadata['Lecture Title']}\n")
